# %% [markdown]
# <a href="https://colab.research.google.com/github/tawadros312/Machine-Learning-Track-DSC-Assiut-/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![121263410_628773508004599_6245338273076553323_n.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #Matplotlib

# %% [markdown]
# ##**Basics**

# %%
import matplotlib.pyplot as plt

import numpy as np

# %%
f=[1,2,8,4,5,6]
plt.plot(f)

# %%
x=[1,2,3,4,5,6]
y=[1,4,9,16,0,3]
plt.plot(x,y)
plt.xlabel("x number ")
plt.ylabel("y number ")
plt.show()

# %% [markdown]
# ##**Color**

# %%
x= np.arange(0.,10,0.1)
a=np.sin(x)
plt.plot(x,a,'r',label='sine')
plt.show()

# %% [markdown]
# ##**Line-style**

# %%
color = 'cornflowerblue'
points = np.ones(5)  # Draw 5 points for each line
text_style = dict(horizontalalignment='right', verticalalignment='center',
                  fontsize=12, fontdict={'family': 'monospace'})


def format_axes(ax):
    ax.margins(0.2)
    ax.set_axis_off()


# Plot all line styles.
fig, ax = plt.subplots()

linestyles = ['-', '--', '-.', ':']
for y, linestyle in enumerate(linestyles):
    ax.text(-0.1, y, repr(linestyle), **text_style)
    ax.plot(y * points, linestyle=linestyle, color=color, linewidth=3)
    format_axes(ax)
    ax.set_title('line styles')

plt.show()

# %% [markdown]
# ##**Subplotting**

# %%
fig, axarr = plt.subplots(2, 1, figsize=(12, 8))

# %%
ax11 = plt.subplot(2, 2, 1)
ax21 = plt.subplot(2, 2, 2)
ax12 = plt.subplot(2, 2, 3)
ax22 = plt.subplot(2, 2, 4)

# %%
ax11 = plt.subplot(2, 2, 1)
ax21 = plt.subplot(2, 2, 2)
ax2 = plt.subplot(2, 1, 2)

# %%
sin = np.sin(np.linspace(-4, 4, 100))
plt.subplot(2, 2, 1)
plt.plot(sin)
plt.subplot(2, 2, 2)
plt.plot(sin, c='r')

# %%
fig, axes = plt.subplots(2, 2)
axes[0, 0].plot(sin)
axes[0, 1].plot(sin, c='r')

# %%
fig, ax = plt.subplots(2, 4, figsize=(10, 5))
ax[0, 0].plot(sin)
ax[0, 1].plot(range(100), sin)  # same as above
ax[0, 2].plot(np.linspace(-4, 4, 100), sin)
ax[0, 3].plot(sin[::10], 'o')
ax[1, 0].plot(sin, c='r')
ax[1, 1].plot(sin, '--')
ax[1, 2].plot(sin, lw=3)
ax[1, 3].plot(sin[::10], '--o')

# %% [markdown]
# ##**Histogram**

# %%
fig, ax = plt.subplots(1, 3, figsize=(10, 3))
ax[0].hist(np.random.normal(size=1000))
ax[1].hist(np.random.normal(size=1000), bins=100)
ax[2].hist(np.random.normal(size=1000), bins="auto")
# Out:
# (array([  8.,   5.,  15.,  14.,  34.,  47.,  60.,  81.,  94., 112.,  91.,
#          98.,  91.,  77.,  65.,  36.,  20.,  18.,  16.,   9.,   6.,   3.]),
#  array([-2.65798613, -2.40435511, -2.15072409, -1.89709307, -1.64346205,
#         -1.38983103, -1.13620001, -0.88256899, -0.62893797, -0.37530695,
#         -0.12167593,  0.13195508,  0.3855861 ,  0.63921712,  0.89284814,
#          1.14647916,  1.40011018,  1.6537412 ,  1.90737222,  2.16100324,
#          2.41463426,  2.66826528,  2.9218963 ]),
#  <a list of 22 Patch objects>)

# %% [markdown]
# ##**Bar Charts**

# %%
objects = ('Python', 'C++', 'Java', 'Perl', 'Scala', 'Lisp')
y_pos = np.arange(len(objects))
performance = [10,8,6,4,2,1]

plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Usage')
plt.title('Programming language usage')

plt.show()

# %% [markdown]
# ##**Scatter plot**

# %%
n=500
x= np.random.normal(0,1,n)
y= np.random.normal(0,1,n)
plt.scatter(x,y)
plt.show()

# %% [markdown]
# ##**Matplotlib pie chart**

# %%
import matplotlib.pyplot as plt

# Data to plot
labels = 'Python', 'C++', 'Ruby', 'Java'
sizes = [215, 130, 245, 210]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()

# %% [markdown]
# ##**Heatmap**

# %%
import matplotlib.pyplot as plt
import numpy as np

a = np.random.random((16, 16))
plt.imshow(a, cmap='hot', interpolation='nearest')
plt.show()

# %%
def heatmap2d(arr: np.ndarray):
    plt.imshow(arr, cmap='viridis')
    plt.colorbar()
    plt.show()


test_array = np.arange(100 * 100).reshape(100, 100)
heatmap2d(test_array)

# %% [markdown]
# ##**Things to search for **
#
#
# hexgrids
#
#
# twinx ,twiny
#
# 3d plotting
